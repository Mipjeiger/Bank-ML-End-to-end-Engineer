# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)
df = pd.read_parquet("eda_banking.parquet")
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure     Balance  NumOfProducts  \
# 0             619    France  Female   42       2  11983969.0              1
# 1             608     Spain  Female   41       1   8380786.0              1
# 2             502    France  Female   42       8  15966080.0              3
# 3             699    France  Female   39       1  11983969.0              2
# 4             850     Spain  Female   43       2  12551082.0              1
# ...           ...       ...     ...  ...     ...         ...            ...
# 9995          771    France    Male   39       5  11983969.0              2
# 9996          516    France    Male   35      10   5736961.0              1
# 9997          709    France  Female   36       7  11983969.0              1
# 9998          772   Germany    Male   42       3   7507531.0              2
# 9999          792    France  Female   28       4  13014279.0              1
#
# ...

# %%
df["event_timestamp"] = pd.date_range(start="2024-01-01", periods=len(df), freq="T")

# Create a unique customer_id for each row
df["customer_id"] = [f"ADX_{i}" for i in range(len(df))]
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure     Balance  NumOfProducts  \
# 0             619    France  Female   42       2  11983969.0              1
# 1             608     Spain  Female   41       1   8380786.0              1
# 2             502    France  Female   42       8  15966080.0              3
# 3             699    France  Female   39       1  11983969.0              2
# 4             850     Spain  Female   43       2  12551082.0              1
# ...           ...       ...     ...  ...     ...         ...            ...
# 9995          771    France    Male   39       5  11983969.0              2
# 9996          516    France    Male   35      10   5736961.0              1
# 9997          709    France  Female   36       7  11983969.0              1
# 9998          772   Germany    Male   42       3   7507531.0              2
# 9999          792    France  Female   28       4  13014279.0              1
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df['event_timestamp'].to_dict()
# Out:
# {0: Timestamp('2024-01-01 00:00:00'),
#  1: Timestamp('2024-01-01 00:01:00'),
#  2: Timestamp('2024-01-01 00:02:00'),
#  3: Timestamp('2024-01-01 00:03:00'),
#  4: Timestamp('2024-01-01 00:04:00'),
#  5: Timestamp('2024-01-01 00:05:00'),
#  6: Timestamp('2024-01-01 00:06:00'),
#  7: Timestamp('2024-01-01 00:07:00'),
#  8: Timestamp('2024-01-01 00:08:00'),
#  9: Timestamp('2024-01-01 00:09:00'),
#  10: Timestamp('2024-01-01 00:10:00'),
#  11: Timestamp('2024-01-01 00:11:00'),
#  12: Timestamp('2024-01-01 00:12:00'),
#  13: Timestamp('2024-01-01 00:13:00'),
#  14: Timestamp('2024-01-01 00:14:00'),
#  15: Timestamp('2024-01-01 00:15:00'),
#  16: Timestamp('2024-01-01 00:16:00'),
#  17: Timestamp('2024-01-01 00:17:00'),
#  18: Timestamp('2024-01-01 00:18:00'),
#  19: Timestamp('2024-01-01 00:19:00'),
#  20: Timestamp('2024-01-01 00:20:00'),
#  21: Timestamp('2024-01-01 00:21:00'),
#  22: Timestamp('2024-01-01 00:22:00'),
#  23: Timestamp('2024-01-01 00:23:00'),
# ...

# %%
pd.DataFrame(df['customer_id'])
# Out:
#      customer_id
# 0          ADX_0
# 1          ADX_1
# 2          ADX_2
# 3          ADX_3
# 4          ADX_4
# ...          ...
# 9995    ADX_9995
# 9996    ADX_9996
# 9997    ADX_9997
# 9998    ADX_9998
# 9999    ADX_9999
#
# [10000 rows x 1 columns]

# %%
pd.read_parquet("eda_banking.parquet")
# Out:
#       CreditScore Geography  Gender  Age  Tenure     Balance  NumOfProducts  \
# 0             619    France  Female   42       2  11983969.0              1
# 1             608     Spain  Female   41       1   8380786.0              1
# 2             502    France  Female   42       8  15966080.0              3
# 3             699    France  Female   39       1  11983969.0              2
# 4             850     Spain  Female   43       2  12551082.0              1
# ...           ...       ...     ...  ...     ...         ...            ...
# 9995          771    France    Male   39       5  11983969.0              2
# 9996          516    France    Male   35      10   5736961.0              1
# 9997          709    France  Female   36       7  11983969.0              1
# 9998          772   Germany    Male   42       3   7507531.0              2
# 9999          792    France  Female   28       4  13014279.0              1
#
# ...

# %%
df[df['customer_id', 'Fraud']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('customer_id', 'Fraud')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['HighValueCustomer'].value_counts()
# Out:
# HighValueCustomer
# 0    5201
# 1    4799
# Name: count, dtype: int64

# %%
df['ComplainFlag'].value_counts()
# Out:
# ComplainFlag
# 0    7956
# 1    2044
# Name: count, dtype: int64
